# %% [markdown]
# ## Linear Regression Assignment

# %%
import pandas as pd
import numpy as np

# %%
s=pd.read_excel('Linear Regression.xlsx')

# %%
s.head(10)
# Out:
#      price  sqft_living  bedrooms  bathrooms  floors
# 0   221900         1180         3       1.00     1.0
# 1   538000         2570         3       2.25     2.0
# 2   180000          770         2       1.00     1.0
# 3   604000         1960         4       3.00     1.0
# 4   510000         1680         3       2.00     1.0
# 5  1225000         5420         4       4.50     1.0
# 6   257500         1715         3       2.25     2.0
# 7   291850         1060         3       1.50     1.0
# 8   229500         1780         3       1.00     1.0
# 9   323000         1890         3       2.50     2.0

# %% [markdown]
# #### checking null values

# %%
s.isnull().sum()
# Out:
# price          0
# sqft_living    0
# bedrooms       0
# bathrooms      0
# floors         0
# dtype: int64

# %% [markdown]
# #### no null values present

# %%
s.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000021B0DD1AC48>,
# ...
#       dtype=object)

# %%
s.corr()
# Out:
#                 price  sqft_living  bedrooms  bathrooms    floors
# price        1.000000     0.702035  0.308350   0.525138  0.256794
# sqft_living  0.702035     1.000000  0.576671   0.754665  0.353949
# bedrooms     0.308350     0.576671  1.000000   0.515884  0.175429
# bathrooms    0.525138     0.754665  0.515884   1.000000  0.500653
# floors       0.256794     0.353949  0.175429   0.500653  1.000000

# %% [markdown]
# ##### sqft_living shows high  positive correlation with price whereas bedrooms and floors show low positive correlation and  bathrooms shows a medium positive correlation with price

# %%
import seaborn as sns

# %%
sns.pairplot(s)

# %% [markdown]
# ## Price and Square feet

# %%
x=s.iloc[:,:1]
y=s.iloc[:,1:2]
print(x)
print(y)
# Out:
#         price
# 0      221900
# 1      538000
# 2      180000
# 3      604000
# 4      510000
# ...       ...
# 21608  360000
# 21609  400000
# 21610  402101
# 21611  400000
# 21612  325000
#
# [21613 rows x 1 columns]
#        sqft_living
# 0             1180
# 1             2570
# 2              770
# 3             1960
# 4             1680
# ...            ...
# 21608         1530
# 21609         2310
# 21610         1020
# 21611         1600
# 21612         1020
#
# [21613 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)
plt.xlabel("price of house")
plt.ylabel("square feet")
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
lin_reg=LinearRegression()
lin_reg.fit(X_train,Y_train)
plt.scatter(X_train,Y_train,color='red')
plt.plot(X_train,lin_reg.predict(X_train),color='blue')
plt.show()

# %%
from sklearn.metrics import mean_squared_error,r2_score
y_pred=lin_reg.predict(X_test)
rmse=np.sqrt(mean_squared_error(Y_test,y_pred))
r_square=r2_score(Y_test,y_pred)
print(rmse,r_square)
# Out:
# 647.3715598616461 0.4813925927530154

# %% [markdown]
# #### As the value of r-square is 0.4813, this means the performance is around 48% of the dataset
# #### error in the table value and predicted value is 647.371

# %% [markdown]
# ## Price and  Bedroom

# %%
x=s.iloc[:,:1]
y=s.iloc[:,2:3]
print(x)
print(y)
# Out:
#         price
# 0      221900
# 1      538000
# 2      180000
# 3      604000
# 4      510000
# ...       ...
# 21608  360000
# 21609  400000
# 21610  402101
# 21611  400000
# 21612  325000
#
# [21613 rows x 1 columns]
#        bedrooms
# 0             3
# 1             3
# 2             2
# 3             4
# 4             3
# ...         ...
# 21608         3
# 21609         4
# 21610         2
# 21611         3
# 21612         2
#
# [21613 rows x 1 columns]

# %%
plt.scatter(x,y)
plt.xlabel("price of house")
plt.ylabel("Number of bedrooms")
plt.show()

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.2,random_state=0)
lin_reg.fit(X_train,Y_train)
plt.scatter(X_train,Y_train,color='red')
plt.plot(X_train,lin_reg.predict(X_train),color='blue')
plt.show()

# %%
y_pred=lin_reg.predict(X_test)
rmse=np.sqrt(mean_squared_error(Y_test,y_pred))
r_square=r2_score(Y_test,y_pred)
print(rmse,r_square)
# Out:
# 0.8392153472949243 0.08167735235965379

# %% [markdown]
# #### As the value of r-square is 0.0816, this means the performance is around 9% of the dataset
# #### error in the table value and predicted value is 0.83921
# ##### ie this is a bad performance model

# %% [markdown]
# ## Price and Bathrooms

# %%
x=s.iloc[:,:1]
y=s.iloc[:,3:4]
print(x)
print(y)
# Out:
#         price
# 0      221900
# 1      538000
# 2      180000
# 3      604000
# 4      510000
# ...       ...
# 21608  360000
# 21609  400000
# 21610  402101
# 21611  400000
# 21612  325000
#
# [21613 rows x 1 columns]
#        bathrooms
# 0           1.00
# 1           2.25
# 2           1.00
# 3           3.00
# 4           2.00
# ...          ...
# 21608       2.50
# 21609       2.50
# 21610       0.75
# 21611       2.50
# 21612       0.75
#
# [21613 rows x 1 columns]

# %%
plt.scatter(x,y)
plt.xlabel("price of house")
plt.ylabel("bathrooms")
plt.show()

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.2,random_state=0)
lin_reg.fit(X_train,Y_train)
plt.scatter(X_train,Y_train,color='red')
plt.plot(X_train,lin_reg.predict(X_train),color='blue')
plt.show()

# %%
y_pred=lin_reg.predict(X_test)
rmse=np.sqrt(mean_squared_error(Y_test,y_pred))
r_square=r2_score(Y_test,y_pred)
print(rmse,r_square)
# Out:
# 0.6483653914122122 0.2752508749094048

# %% [markdown]
# #### As the value of r-square is 0.2752, this means the performance is around 27% of the dataset
# #### error in the table value and predicted value is 648.365
# #### ie it is not a good performance model

# %% [markdown]
# ## Price and floors

# %%
x=s.iloc[:,:1]
y=s.iloc[:,4:5]
print(x)
print(y)
# Out:
#         price
# 0      221900
# 1      538000
# 2      180000
# 3      604000
# 4      510000
# ...       ...
# 21608  360000
# 21609  400000
# 21610  402101
# 21611  400000
# 21612  325000
#
# [21613 rows x 1 columns]
#        floors
# 0         1.0
# 1         2.0
# 2         1.0
# 3         1.0
# 4         1.0
# ...       ...
# 21608     3.0
# 21609     2.0
# 21610     2.0
# 21611     2.0
# 21612     2.0
#
# [21613 rows x 1 columns]

# %%
plt.scatter(x,y)
plt.xlabel("price of house")
plt.ylabel("number of floors")
plt.show()

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.2,random_state=0)
lin_reg.fit(X_train,Y_train)
plt.scatter(X_train,Y_train,color='red')
plt.plot(X_train,lin_reg.predict(X_train),color='blue')
plt.show()

# %%
y_pred=lin_reg.predict(X_test)
rmse=np.sqrt(mean_squared_error(Y_test,y_pred))
r_square=r2_score(Y_test,y_pred)
print(rmse,r_square)
# Out:
# 0.5106035326379263 0.06883851352598913

# %% [markdown]
# #### As the value of r-square is 0.068, this means the performance is around 7% of the dataset
# #### error in the table value and predicted value is 0.510
# ##### ie it is also not a good performance model
